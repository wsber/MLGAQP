# %% [markdown]
# #### 将精确子图匹配结果中满足多个推理谓词Oracle条件的结果保存下来

# %%
# 1. 启用自动重载，确保修改后的 .py 文件能立即生效
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# --- 路径设置 (根据你的 Notebook 所在位置调整) ---
# 如果你的 Notebook 在 pythonProject 根目录下：
# from src.Structure_first.compute_truth import GroundTruthManager

# 如果你的 Notebook 在 src/Structure_first/ 目录下：
# from compute_truth import GroundTruthManager

# 通用方式：将项目根目录加入系统路径
project_root = "/home/wangshuo/projects/Neo4j_Exp/pythonProject"
if project_root not in sys.path:
    sys.path.append(project_root)

from src.Structure_first.compute_truth import GroundTruthManager

# 2. 初始化管理器
# 请将 "dataset_name" 替换为你实际的数据集名称 (例如 "parler_data_1" 或其他)
dataset_name = "dataset_test2"  
gt_manager = GroundTruthManager(dataset_name)

# 3. 执行保存任务
# 这将读取所有 _matches.csv，过滤不满足 Oracle 的行，并保存为 _filtered.csv
# 进度条会在下方显示
gt_manager.save_all_filtered_matches(output_dir_name='/home/wangshuo/resource/datasets/parler_data/dataset_test2/ground_truth/structure_oracle_result_label2')
# Out:
# 📂 准备将过滤后的结果保存到: /home/wangshuo/resource/datasets/parler_data/dataset_test2/ground_truth/structure_oracle_result_label2
# 已成功预加载 id_mapping, post, 和 comment 数据。
# 过滤查询进度: 100%|██████████| 290/290 [02:47<00:00,  1.74file/s]
