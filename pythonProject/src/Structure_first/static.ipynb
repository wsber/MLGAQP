# %% [markdown]
# 输入的图名称为parler_0.graph文件， 按照顶点的标签降序排序，结果输出到parler_1.graph，并统计每个标签下有多少节点

# %%
import collections

input_file = "/home/wangshuo/projects/FaSTest-main/dataset/parler_0/parler_0.graph"
output_file = "/home/wangshuo/projects/FaSTest-main/dataset/parler_0/parler_1.graph"

# 读取文件
with open(input_file, "r") as f:
    lines = f.readlines()

header = None
vertices = []
edges = []

for line in lines:
    if line.startswith("t"):
        header = line.strip().split()
    elif line.startswith("v"):
        parts = line.strip().split()
        vid = int(parts[1])
        label = int(parts[2])
        degree = int(parts[3])
        vertices.append((vid, label, degree))
    elif line.startswith("e"):
        parts = line.strip().split()
        src = int(parts[1])
        dst = int(parts[2])
        elabel = int(parts[3]) if len(parts) > 3 else 0
        edges.append((src, dst, elabel))

# 按 label 升序排序（保持 ID 不变）
vertices_sorted = sorted(vertices, key=lambda x: x[1])

# 统计每个标签的节点数量
label_count = collections.Counter([label for (_, label, _) in vertices_sorted])

print("标签统计（Label -> 节点数）:")
for label, count in sorted(label_count.items()):
    print(f"  {label}: {count}")

# 输出新文件
with open(output_file, "w") as f:
    f.write(f"t {len(vertices_sorted)} {len(edges)}\n")
    for vid, label, degree in vertices_sorted:
        f.write(f"v {vid} {label} {degree}\n")
    for src, dst, elabel in edges:
        if elabel != 0:
            f.write(f"e {src} {dst} {elabel}\n")
        else:
            f.write(f"e {src} {dst}\n")

print(f"\n✅ 已生成文件: {output_file}")
# Out:
# 标签统计（Label -> 节点数）:
#   0: 434
#   1: 30
#   2: 622
#   3: 287
#   4: 97
#   5: 15
#   6: 132
#   7: 83
#   8: 131
#   9: 1
#   10: 8
#   11: 11
#   12: 197
#   13: 6
#   14: 72
#   15: 8
#   16: 55
#   17: 84
#   18: 16
#   19: 83
#   20: 12
#   21: 1
#   22: 38
#   23: 8
#   24: 38
#   25: 16
#   26: 22
#   27: 14
#   28: 29
#   29: 4
#   30: 5
#   31: 12
#   32: 5
#   33: 22
#   34: 1
#   35: 3
#   36: 331
#   37: 1
#   38: 2
#   39: 14
#   40: 28
#   41: 2
#   42: 8
#   43: 9
#   44: 28
#   45: 15
#   46: 10
#   47: 9
#   48: 3
#   49: 1
#   50: 3
#   51: 2
#   52: 2
#   53: 2
#   54: 10
#   55: 1
#   56: 1
#   57: 2
#   58: 3
#   59: 5
#   60: 2
#   61: 2
#   62: 1
#   63: 1
#   64: 4
#   65: 2
#   66: 2
#   67: 1
#   68: 1
#   69: 1
#   70: 1
#
# ✅ 已生成文件: /home/wangshuo/projects/FaSTest-main/dataset/parler_0/parler_1.graph

# %% [markdown]
# 读取标签为x的所有节点，将这些节点的id保存到/home/wangshuo/projects/FaSTest-main/dataset/sv/parler_0/sv.txt文件夹下

# %%
import os
from collections import defaultdict

# ==== 可修改参数 ====
input_file = "/home/wangshuo/projects/FaSTest-main/dataset/parler_0/parler_0.graph"
output_dir = "/home/wangshuo/projects/FaSTest-main/dataset/sv/svs"
# ====================

# === 1. 读取图文件 ===
label_to_nodes = defaultdict(list)

with open(input_file, "r") as f:
    for line in f:
        if line.startswith("v"):
            parts = line.strip().split()
            if len(parts) >= 3:
                vid = int(parts[1])
                label = int(parts[2])
                label_to_nodes[label].append(vid)

# === 2. 检查是否有节点 ===
if not label_to_nodes:
    print("[错误] 没有在图文件中找到任何顶点行（以 'v' 开头）。")
    exit()

# === 3. 确保输出文件夹存在 ===
os.makedirs(output_dir, exist_ok=True)

# === 4. 为每个标签单独保存文件 ===
for label, vids in sorted(label_to_nodes.items()):
    output_file = os.path.join(output_dir, f"sv_{label}.txt")
    with open(output_file, "w") as f:
        for vid in vids:
            f.write(f"{vid}\n")
    print(f"✅ 标签 {label}: {len(vids)} 个节点 -> {output_file}")

# === 5. 总结 ===
total_nodes = sum(len(v) for v in label_to_nodes.values())
print(f"\n🎯 共处理 {len(label_to_nodes)} 个标签，总节点数 {total_nodes}")
# Out:
# ✅ 标签 0: 434 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_0.txt
# ✅ 标签 1: 30 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_1.txt
# ✅ 标签 2: 622 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_2.txt
# ✅ 标签 3: 287 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_3.txt
# ✅ 标签 4: 97 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_4.txt
# ✅ 标签 5: 15 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_5.txt
# ✅ 标签 6: 132 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_6.txt
# ✅ 标签 7: 83 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_7.txt
# ✅ 标签 8: 131 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_8.txt
# ✅ 标签 9: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_9.txt
# ✅ 标签 10: 8 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_10.txt
# ✅ 标签 11: 11 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_11.txt
# ✅ 标签 12: 197 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_12.txt
# ✅ 标签 13: 6 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_13.txt
# ✅ 标签 14: 72 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_14.txt
# ✅ 标签 15: 8 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_15.txt
# ✅ 标签 16: 55 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_16.txt
# ✅ 标签 17: 84 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_17.txt
# ✅ 标签 18: 16 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_18.txt
# ✅ 标签 19: 83 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_19.txt
# ✅ 标签 20: 12 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_20.txt
# ✅ 标签 21: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_21.txt
# ✅ 标签 22: 38 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_22.txt
# ✅ 标签 23: 8 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_23.txt
# ✅ 标签 24: 38 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_24.txt
# ✅ 标签 25: 16 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_25.txt
# ✅ 标签 26: 22 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_26.txt
# ✅ 标签 27: 14 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_27.txt
# ✅ 标签 28: 29 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_28.txt
# ✅ 标签 29: 4 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_29.txt
# ✅ 标签 30: 5 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_30.txt
# ✅ 标签 31: 12 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_31.txt
# ✅ 标签 32: 5 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_32.txt
# ✅ 标签 33: 22 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_33.txt
# ✅ 标签 34: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_34.txt
# ✅ 标签 35: 3 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_35.txt
# ✅ 标签 36: 331 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_36.txt
# ✅ 标签 37: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_37.txt
# ✅ 标签 38: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_38.txt
# ✅ 标签 39: 14 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_39.txt
# ✅ 标签 40: 28 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_40.txt
# ✅ 标签 41: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_41.txt
# ✅ 标签 42: 8 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_42.txt
# ✅ 标签 43: 9 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_43.txt
# ✅ 标签 44: 28 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_44.txt
# ✅ 标签 45: 15 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_45.txt
# ✅ 标签 46: 10 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_46.txt
# ✅ 标签 47: 9 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_47.txt
# ✅ 标签 48: 3 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_48.txt
# ✅ 标签 49: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_49.txt
# ✅ 标签 50: 3 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_50.txt
# ✅ 标签 51: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_51.txt
# ✅ 标签 52: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_52.txt
# ✅ 标签 53: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_53.txt
# ✅ 标签 54: 10 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_54.txt
# ✅ 标签 55: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_55.txt
# ✅ 标签 56: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_56.txt
# ✅ 标签 57: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_57.txt
# ✅ 标签 58: 3 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_58.txt
# ✅ 标签 59: 5 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_59.txt
# ✅ 标签 60: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_60.txt
# ✅ 标签 61: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_61.txt
# ✅ 标签 62: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_62.txt
# ✅ 标签 63: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_63.txt
# ✅ 标签 64: 4 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_64.txt
# ✅ 标签 65: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_65.txt
# ✅ 标签 66: 2 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_66.txt
# ✅ 标签 67: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_67.txt
# ✅ 标签 68: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_68.txt
# ✅ 标签 69: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_69.txt
# ✅ 标签 70: 1 个节点 -> /home/wangshuo/projects/FaSTest-main/dataset/sv/svs/sv_70.txt
#
# 🎯 共处理 71 个标签，总节点数 3112

# %% [markdown]
# 在 /home/wangshuo/projects/FaSTest-main/dataset/yeast/query_graph文件夹下搜索包含标签为x的查询，并将这些查询保存到文件夹/home/wangshuo/projects/FaSTest-main/dataset/partition_data/query_x_graph下，同时将/home/wangshuo/projects/FaSTest-main/dataset/yeast 下的 yeast_ans.txt 对应的真实答案写到 /home/wangshuo/projects/FaSTest-main/dataset/partition_data/的 ans.txt中

# %%
import os
import shutil

# === 参数设置 ===
LABEL = "6"  # 要搜索的节点标签（字符串类型）
query_dir = "/home/wangshuo/projects/FaSTest-main/dataset/yeast/query_graph"
ans_file = "/home/wangshuo/projects/FaSTest-main/dataset/yeast/yeast_ans.txt"
out_query_dir = f"/home/wangshuo/projects/FaSTest-main/dataset/partition_data/query_{LABEL}_graph"
out_ans_file = f"/home/wangshuo/projects/FaSTest-main/dataset/partition_data/query_{LABEL}_ans.txt"

os.makedirs(out_query_dir, exist_ok=True)

# === Step 1. 搜索包含指定标签的查询图 ===
selected_queries = set()

for fname in os.listdir(query_dir):
    if not fname.endswith(".graph"):
        continue
    fpath = os.path.join(query_dir, fname)
    try:
        contains_label = False
        with open(fpath, "r") as f:
            for line in f:
                line = line.strip()
                if not line or not line.startswith("v"):
                    continue
                parts = line.split()
                if len(parts) < 3:
                    continue
                vertex_label = parts[2]  # v [id] [label] [degree]
                if vertex_label == LABEL:
                    contains_label = True
                    break
        if contains_label:
            selected_queries.add(fname)
            shutil.copy(fpath, os.path.join(out_query_dir, fname))
    except Exception as e:
        print(f"[Warning] Failed to read {fname}: {e}")

print(f"[Info] 共选中了 {len(selected_queries)} 个包含标签 {LABEL} 的查询文件。")

# === Step 2. 过滤 yeast_ans.txt ===
num_ans_written = 0
with open(ans_file, "r") as fin, open(out_ans_file, "w") as fout:
    for line in fin:
        parts = line.strip().split()
        if len(parts) < 2:
            continue
        qname = parts[0]
        # 有的答案文件可能没有 .graph 后缀
        if qname.endswith(".graph") and qname in selected_queries:
            fout.write(line)
            num_ans_written += 1
        else:
            qfile = os.path.basename(qname)
            if not qfile.endswith(".graph"):
                qfile = qfile + ".graph"
            if qfile in selected_queries:
                fout.write(line)
                num_ans_written += 1

print(f"[Info] 已写入过滤后的真实答案文件：{out_ans_file}")
print(f"[Info] 共保留 {num_ans_written} 条答案记录。")
# Out:
# [Info] 共选中了 242 个包含标签 6 的查询文件。
# [Info] 已写入过滤后的真实答案文件：/home/wangshuo/projects/FaSTest-main/dataset/partition_data/query_6_ans.txt
# [Info] 共保留 224 条答案记录。

# %% [markdown]
# 读取sv_estimate_result.txt第二列并相加，同时计算与真实值n=15981742的log(Q_error)误差

# %%
import math
import re

# === 文件路径 ===
est_file = "/home/wangshuo/projects/FaSTest-main/dataset/sv/sv_estimate_result.txt"
ans_file = "/home/wangshuo/projects/FaSTest-main/dataset/yeast_exp/yeast_exp_ans.txt"

# === 读取真实值 ===
true_values = {}
with open(ans_file, "r") as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) >= 3:
            query_name = parts[0].strip()  # e.g. query_dense_8_106.graph
            try:
                true_val = float(parts[-1])  # 最后一列是结果
                true_values[query_name] = true_val
            except ValueError:
                pass

# === 读取估计结果 ===
results = {}
current_query = None
current_sum = 0.0

with open(est_file, "r") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Query:"):
            # 保存上一个 query 的结果
            if current_query is not None:
                results[current_query] = current_sum
            # 提取新 query 名称
            m = re.search(r"([^/\\]+\.graph)", line)
            if m:
                current_query = m.group(1)
                current_sum = 0.0
        elif line.startswith("----------------------------------------"):
            if current_query is not None:
                results[current_query] = current_sum
                current_query = None
        else:
            parts = line.split()
            if len(parts) >= 2:
                try:
                    val = float(parts[1])
                    current_sum += val
                except ValueError:
                    pass
# 最后一段
if current_query is not None:
    results[current_query] = current_sum

# === 计算 log(Q_error) 并收集排序用数据 ===
records = []
for q, est_sum in results.items():
    true_val = true_values.get(q)
    if true_val is None or true_val <= 0 or est_sum <= 0:
        log_q_error = float("inf")
    else:
        q_error = max(est_sum / true_val, true_val / est_sum)
        log_q_error = math.log10(q_error)
    records.append((q, est_sum, true_val, log_q_error))

# === 按 log(Q_error) 降序排列 ===
records.sort(key=lambda x: (float("inf") if math.isnan(x[3]) else x[3]), reverse=True)

# === 输出结果 ===
print(f"{'Query':40} {'EstimateSum':>15} {'TrueVal':>15} {'log(Q_error)':>15}")
print("-" * 90)
for q, est_sum, true_val, log_q_error in records:
    if true_val is None:
        print(f"{q:40} {est_sum:15.8f} {'N/A':>15} {'N/A':>15}")
    elif math.isinf(log_q_error):
        print(f"{q:40} {est_sum:15.8f} {true_val:15.0f} {'INF':>15}")
    else:
        print(f"{q:40} {est_sum:15.8f} {true_val:15.0f} {log_q_error:15.8f}")
# Out:
# Query                                        EstimateSum         TrueVal    log(Q_error)
# ------------------------------------------------------------------------------------------
# query_dense_16_13.graph                       0.00000000     27393181550             INF
# query_dense_16_46.graph                       0.00000000         7431000             INF
# query_dense_24_2.graph                        0.00000000        71689513             INF
# query_dense_24_22.graph                       0.00000000         4449532             INF
# query_dense_24_39.graph                       0.00000000        15226880             INF
# query_dense_24_61.graph                       0.00000000        53111964             INF
# query_dense_32_49.graph                       0.00000000       133237581             INF
# query_sparse_24_22.graph                      0.00000000    561722326048             INF
# query_sparse_32_183.graph                     0.00000000 95470717314382624             INF
# query_sparse_32_175.graph                     0.00000000     86851326330             INF
# query_sparse_32_122.graph                     0.00000000    147303210616             INF
# query_sparse_32_197.graph                152348000000000.00000000 174029665905486      0.05778653
# query_dense_32_192.graph                 153264.00000000          174940      0.05744897
# query_sparse_32_128.graph                23749100000000.00000000  27102063482344      0.05735520
# query_sparse_16_191.graph                217857500.00000000       248581938      0.05729705
# query_dense_16_79.graph                  919138000.00000000       805779141      0.05716470
# query_sparse_32_167.graph                2736310000.00000000      3117012624      0.05657326
# query_dense_16_184.graph                 123288200.00000000       140256627      0.05600188
# query_dense_8_124.graph                  39907619.00000000        35100324      0.05574469
# query_dense_16_124.graph                  46917.00000000           53340      0.05572278
# query_sparse_32_43.graph                 4679840000.00000000      5316090741      0.05536138
# query_sparse_32_25.graph                 189082000000000000.00000000 214644656569289248      0.05506989
# query_dense_24_12.graph                  4335530000.00000000      3819575411      0.05502711
# query_sparse_32_31.graph                 17404800000000.00000000  15347513570401      0.05463101
# query_sparse_24_16.graph                 233914000000.00000000    206466674400      0.05420625
# query_sparse_24_179.graph                168456000.00000000       190829608      0.05415927
# query_sparse_16_149.graph                83137090.00000000        73442067      0.05384993
# query_dense_32_58.graph                  165415000.00000000       187220010      0.05377737
# query_sparse_32_112.graph                502669000.00000000       568857468      0.05372136
# query_sparse_8_2.graph                   197551.74000000          223367      0.05333815
# query_dense_24_63.graph                  2477940000.00000000      2800419040      0.05313224
# query_sparse_24_139.graph                66370900.00000000        74934537      0.05270432
# query_sparse_24_184.graph                515748000000.00000000    456884223214      0.05263139
# query_sparse_32_19.graph                 806996000.00000000       715432536      0.05230270
# query_sparse_16_200.graph                3583880000.00000000      3177771152      0.05223084
# query_sparse_16_161.graph                885940.00000000          785623      0.05219012
# query_dense_16_5.graph                     1120.45000000             994      0.05200610
# query_sparse_32_165.graph                481765000000.00000000    427625170306      0.05177199
# query_dense_32_181.graph                 17684100.00000000        15702560      0.05161250
# query_dense_8_65.graph                   350714.40000000          311664      0.05126696
# query_sparse_32_110.graph                837668000.00000000       744648864      0.05112039
# query_sparse_16_153.graph                143298.00000000          127392      0.05109797
# query_sparse_24_7.graph                  3732420000.00000000      3318790522      0.05101067
# query_dense_24_33.graph                  403952.00000000          453566      0.05031073
# query_dense_16_128.graph                 1017290.00000000          906936      0.04986813
# query_sparse_16_187.graph                1320910.00000000         1177625      0.04986621
# query_sparse_32_92.graph                 829957000.00000000       930809504      0.04980522
# query_dense_16_37.graph                    3988.98000000            4470      0.04944566
# query_sparse_24_165.graph                11188000000000.00000000   9989612731274      0.04920381
# query_sparse_8_28.graph                  3913063.00000000         3494510      0.04913055
# query_dense_16_196.graph                 1016242.70000000          907594      0.04910582
# query_dense_16_60.graph                     353.79600000             316      0.04906584
# query_sparse_24_35.graph                 289244310000000.00000000 323767360187411      0.04896824
# query_sparse_16_93.graph                 20253440000.00000000     22654112846      0.04864826
# query_sparse_32_28.graph                 19664300000.00000000     21993506910      0.04861599
# query_dense_32_157.graph                 7022700000.00000000      7853460086      0.04855692
# query_dense_16_162.graph                 4784221.00000000         4280338      0.04833317
# query_sparse_32_81.graph                 124394000000000.00000000 111387928273875      0.04796131
# query_dense_16_173.graph                 2261798.00000000         2027702      0.04744969
# query_sparse_16_117.graph                709702000.00000000       741587792      0.01908654
# query_sparse_32_22.graph                 35271200.00000000        33754810      0.01908457
# query_sparse_32_107.graph                223141000000.00000000    213567561387      0.01904409
# query_dense_32_167.graph                 41668900.00000000        43530144      0.01897807
# query_sparse_24_163.graph                42771300.00000000        40944056      0.01896159
# query_dense_32_30.graph                  7220660.00000000         7540640      0.01883131
# query_dense_32_143.graph                 1027840.00000000          984312      0.01879274
# query_dense_16_18.graph                  780147.00000000          814632      0.01878502
# query_sparse_16_19.graph                   5203.97000000            5434      0.01878485
# query_sparse_8_94.graph                    2130.94500000            2225      0.01875777
# query_dense_24_186.graph                 3036250.00000000         3170244      0.01875516
# query_dense_16_198.graph                 164171.00000000          157318      0.01851803
# query_sparse_24_168.graph                3502790.00000000         3655123      0.01848789
# query_dense_32_193.graph                 3722240000.00000000      3567535104      0.01843612
# query_dense_16_190.graph                    705.53600000             736      0.01835864
# query_sparse_16_180.graph                110360870.00000000       105795904      0.01834626
# query_dense_24_116.graph                 443442.00000000          425100      0.01834572
# query_dense_32_165.graph                   3917.95000000            3756      0.01833331
# query_sparse_24_93.graph                 1438580000.00000000      1500488704      0.01829871
# query_sparse_24_144.graph                5380710000.00000000      5158811982      0.01828989
# query_dense_8_61.graph                    16350.17600000           15678      0.01823177
# query_sparse_24_196.graph                7128720000000.00000000   6835883181002      0.01821692
# query_dense_16_66.graph                  2505900.00000000         2403072      0.01819695
# query_dense_32_136.graph                    845.82000000             882      0.01819064
# query_dense_16_137.graph                 11789200.00000000        12292786      0.01816599
# query_sparse_16_77.graph                 37621300.00000000        39224618      0.01812492
# query_sparse_24_103.graph                4750820000.00000000      4952320353      0.01804015
# query_dense_16_93.graph                  2739360.00000000         2627902      0.01803994
# query_dense_24_155.graph                 6258580.00000000         6004152      0.01802413
# query_dense_24_187.graph                    529.62000000             552      0.01797470
# query_sparse_16_90.graph                 152021.00000000          158440      0.01796125
# query_sparse_32_56.graph                 2688660000.00000000      2579964000      0.01792224
# query_dense_24_42.graph                    1128.52000000            1083      0.01788080
# query_sparse_16_168.graph                16945501000000.00000000  17656660266310      0.01785415
# query_sparse_16_106.graph                465361340000.00000000    484885432811      0.01784884
# query_dense_24_159.graph                 360818000.00000000       375941226      0.01783176
# query_sparse_16_86.graph                  23718.90000000           24707      0.01772547
# query_dense_32_101.graph                   9033.92000000            8673      0.01770689
# query_sparse_24_148.graph                6291020.00000000         6548031      0.01738966
# query_sparse_16_84.graph                    922.48800000             960      0.01731051
# query_sparse_16_99.graph                 223323780.00000000       232402918      0.01730661
# query_sparse_24_130.graph                52342200.00000000        54469428      0.01730084
# query_sparse_32_37.graph                 26767800000000.00000000  27855205198249      0.01729368
# query_sparse_24_66.graph                 23244100000.00000000     22336713460      0.01729346
# query_dense_24_194.graph                  16313.50000000           15680      0.01720109
# query_sparse_16_193.graph                 29175.30000000           30354      0.01720060
# query_dense_24_198.graph                 3943780.00000000         3791944      0.01705077
# query_dense_24_158.graph                    436.80000000             420      0.01703334
# query_dense_4_86.graph                      555.35200000             534      0.01702708
# query_dense_32_53.graph                  343523.00000000          330336      0.01699991
# query_sparse_32_62.graph                 74428100.00000000        71584240      0.01691951
# query_dense_16_150.graph                   9890.48000000           10283      0.01690247
# query_dense_32_180.graph                 404375.00000000          388962      0.01687712
# query_sparse_16_66.graph                 209720000.00000000       201755150      0.01681522
# query_sparse_24_80.graph                 882518000000000.00000000 849171724415530      0.01672805
# query_sparse_24_6.graph                  2157140000.00000000      2241798534      0.01671825
# query_sparse_32_105.graph                2293110000.00000000      2383018560      0.01670254
# query_dense_16_147.graph                  36065.50000000           37476      0.01666127
# query_dense_24_68.graph                  1008580000.00000000      1047870698      0.01659734
# query_sparse_24_20.graph                 300910000000000.00000000 289635435196452      0.01658493
# query_sparse_16_75.graph                   2255.33000000            2171      0.01655027
# query_dense_4_43.graph                     1567.56600000            1509      0.01653660
# query_sparse_16_21.graph                  72934.80000000           75759      0.01649944
# query_sparse_16_98.graph                 1027160.00000000         1066716      0.01641071
# query_sparse_24_183.graph                6217280.00000000         6454464      0.01625976
# query_sparse_24_5.graph                  5320230.00000000         5125014      0.01623535
# query_sparse_32_161.graph                17067900000.00000000     16442911120      0.01620138
# query_dense_8_193.graph                      82.00200000              79      0.01619735
# query_dense_32_87.graph                  3692850.00000000         3557760      0.01618502
# query_dense_32_4.graph                   57886000000.00000000     55788240620      0.01603087
# query_sparse_32_67.graph                 618727000.00000000       641987064      0.01602721
# query_dense_32_42.graph                    2321.84000000            2238      0.01597221
# query_dense_16_12.graph                   48983.70000000           47218      0.01594400
# query_sparse_24_91.graph                 6767810000.00000000      7020290168      0.01590691
# query_dense_24_50.graph                   12723.00000000           12266      0.01588657
# query_dense_24_148.graph                  83096.60000000           80112      0.01588568
# query_dense_24_37.graph                     322.04800000             334      0.01582586
# ...
# query_sparse_32_21.graph                  80015.00000000           79840      0.00095088
# query_sparse_24_3.graph                  2713240000.00000000      2707397220      0.00093623
# query_dense_24_180.graph                 477911.00000000          476886      0.00093245
# query_dense_24_104.graph                 550519.00000000          551686      0.00091965
# query_dense_32_118.graph                  21421.10000000           21376      0.00091533
# query_dense_4_112.graph                     163.66000000             164      0.00090130
# query_sparse_16_79.graph                 154960000000.00000000    154640729057      0.00089572
# query_sparse_24_55.graph                 290729000.00000000       290142608      0.00087684
# query_dense_24_83.graph                   10445.90000000           10425      0.00086980
# query_sparse_24_180.graph                19697000.00000000        19657668      0.00086809
# query_dense_32_132.graph                    120.24000000             120      0.00086772
# query_dense_32_31.graph                  225282.00000000          225709      0.00082238
# query_dense_24_1.graph                   629250.00000000          628095      0.00079789
# query_dense_32_38.graph                      56.10000000              56      0.00077483
# query_dense_4_124.graph                    4440.15000000            4448      0.00076714
# query_dense_32_171.graph                  36165.20000000           36228      0.00075349
# query_dense_4_164.graph                    5320.62800000            5329      0.00068282
# query_dense_32_23.graph                  11529000.00000000        11547130      0.00068242
# query_dense_4_194.graph                      16.97400000              17      0.00066472
# query_dense_32_159.graph                 536380000.00000000       537199415      0.00066296
# query_sparse_24_126.graph                1286890000.00000000      1288801710      0.00064468
# query_dense_24_182.graph                  21311.40000000           21280      0.00064036
# query_dense_4_9.graph                     27519.00500000           27519      0.00000008
# query_dense_4_187.graph                   23215.99600000           23216      0.00000007
# query_dense_4_144.graph                    5911.00100000            5911      0.00000007
# query_dense_4_10.graph                    19677.99800000           19678      0.00000004
# query_dense_4_16.graph                    30877.99800000           30878      0.00000003
# query_dense_4_90.graph                    16052.99900000           16053      0.00000003
# query_dense_4_14.graph                     6674.00000000            6674      0.00000000
# query_dense_4_106.graph                    2198.00000000            2198      0.00000000
# query_dense_4_125.graph                    5369.00000000            5369      0.00000000
# query_dense_4_19.graph                      167.00000000             167      0.00000000
# query_dense_4_117.graph                    6363.00000000            6363      0.00000000
# query_dense_4_128.graph                     460.00000000             460      0.00000000
# query_dense_4_156.graph                     715.00000000             715      0.00000000
# query_dense_4_177.graph                     449.00000000             449      0.00000000
# query_dense_4_186.graph                    5546.00000000            5546      0.00000000
# query_dense_4_199.graph                    1039.00000000            1039      0.00000000
# query_dense_4_3.graph                       172.00000000             172      0.00000000
# query_dense_4_4.graph                         3.00000000               3      0.00000000
# query_dense_4_23.graph                      382.00000000             382      0.00000000
# query_dense_4_52.graph                     5375.00000000            5375      0.00000000
# query_dense_4_76.graph                      403.00000000             403      0.00000000
# query_dense_4_78.graph                      520.00000000             520      0.00000000
# query_dense_4_88.graph                    15750.00000000           15750      0.00000000
# query_dense_4_89.graph                        8.00000000               8      0.00000000
# query_dense_4_100.graph                      65.00000000              65      0.00000000
# query_dense_4_113.graph                    3366.00000000            3366      0.00000000
# query_dense_4_118.graph                      24.00000000              24      0.00000000
# query_dense_4_130.graph                      76.00000000              76      0.00000000
# query_dense_4_132.graph                      21.00000000              21      0.00000000
# query_dense_4_154.graph                     503.00000000             503      0.00000000
# query_dense_4_167.graph                    1510.00000000            1510      0.00000000
# query_dense_4_178.graph                    1092.00000000            1092      0.00000000
# query_dense_4_179.graph                      11.00000000              11      0.00000000
# query_dense_4_190.graph                     588.00000000             588      0.00000000
# query_dense_4_193.graph                      11.00000000              11      0.00000000
# query_dense_4_200.graph                       3.00000000               3      0.00000000
# query_dense_8_33.graph                       12.00000000              12      0.00000000
# query_dense_8_55.graph                     2044.00000000            2044      0.00000000
# query_dense_8_74.graph                       40.00000000              40      0.00000000
# query_dense_8_93.graph                        4.00000000               4      0.00000000
# query_dense_8_104.graph                      40.00000000              40      0.00000000
# query_dense_8_146.graph                     171.00000000             171      0.00000000
# query_dense_8_198.graph                       1.00000000               1      0.00000000
# query_dense_16_2.graph                       36.00000000              36      0.00000000
# query_dense_16_25.graph                     154.00000000             154      0.00000000
# query_dense_16_28.graph                     192.00000000             192      0.00000000
# query_dense_16_32.graph                    3024.00000000            3024      0.00000000
# query_dense_16_33.graph                    3030.00000000            3030      0.00000000
# query_dense_16_51.graph                   42576.00000000           42576      0.00000000
# query_dense_16_67.graph                    1240.00000000            1240      0.00000000
# query_dense_16_88.graph                       6.00000000               6      0.00000000
# query_dense_16_90.graph                    4896.00000000            4896      0.00000000
# query_dense_16_103.graph                     45.00000000              45      0.00000000
# query_dense_16_140.graph                     10.00000000              10      0.00000000
# query_dense_16_142.graph                    112.00000000             112      0.00000000
# query_dense_16_160.graph                     14.00000000              14      0.00000000
# query_dense_16_166.graph                     96.00000000              96      0.00000000
# query_dense_16_193.graph                    180.00000000             180      0.00000000
# query_dense_24_5.graph                        2.00000000               2      0.00000000
# query_dense_24_40.graph                     495.00000000             495      0.00000000
# query_dense_24_71.graph                     128.00000000             128      0.00000000
# query_dense_24_72.graph                     102.00000000             102      0.00000000
# query_dense_24_97.graph                     140.00000000             140      0.00000000
# query_dense_24_101.graph                  44352.00000000           44352      0.00000000
# query_dense_24_105.graph                   3024.00000000            3024      0.00000000
# query_dense_24_107.graph                      8.00000000               8      0.00000000
# query_dense_24_118.graph                    160.00000000             160      0.00000000
# query_dense_24_123.graph                     24.00000000              24      0.00000000
# query_dense_24_128.graph                    432.00000000             432      0.00000000
# query_dense_24_141.graph                  45496.00000000           45496      0.00000000
# query_dense_24_151.graph                     16.00000000              16      0.00000000
# query_dense_24_152.graph                     10.00000000              10      0.00000000
# query_dense_24_160.graph                   1152.00000000            1152      0.00000000
# query_dense_24_163.graph                   4536.00000000            4536      0.00000000
# query_dense_24_165.graph                   1485.00000000            1485      0.00000000
# query_dense_24_174.graph                    192.00000000             192      0.00000000
# query_dense_24_183.graph                    720.00000000             720      0.00000000
# query_dense_24_192.graph                    600.00000000             600      0.00000000
# query_dense_32_2.graph                        1.00000000               1      0.00000000
# query_dense_32_8.graph                      504.00000000             504      0.00000000
# query_dense_32_9.graph                      576.00000000             576      0.00000000
# query_dense_32_19.graph                    1610.00000000            1610      0.00000000
# query_dense_32_56.graph                    4992.00000000            4992      0.00000000
# query_dense_32_64.graph                    1152.00000000            1152      0.00000000
# query_dense_32_74.graph                    5616.00000000            5616      0.00000000
# query_dense_32_79.graph                   15552.00000000           15552      0.00000000
# query_dense_32_82.graph                     504.00000000             504      0.00000000
# query_dense_32_84.graph                    3276.00000000            3276      0.00000000
# query_dense_32_86.graph                    1980.00000000            1980      0.00000000
# query_dense_32_89.graph                      16.00000000              16      0.00000000
# query_dense_32_94.graph                     252.00000000             252      0.00000000
# query_dense_32_111.graph                  48600.00000000           48600      0.00000000
# query_sparse_8_74.graph                     120.00000000             120      0.00000000
# query_sparse_8_146.graph                    171.00000000             171      0.00000000
# query_sparse_8_198.graph                      1.00000000               1      0.00000000
# query_sparse_16_2.graph                      96.00000000              96      0.00000000
# query_sparse_16_32.graph                  11232.00000000           11232      0.00000000
# query_sparse_16_140.graph                    12.00000000              12      0.00000000
# query_dense_32_183.graph                    162.00000000             162      0.00000000
# query_dense_32_138.graph                     36.00000000              36      0.00000000
# query_dense_32_156.graph                   1984.00000000            1984      0.00000000
# query_dense_32_194.graph                    120.00000000             120      0.00000000
# query_dense_32_135.graph                     60.00000000              60      0.00000000
# query_dense_32_147.graph                     24.00000000              24      0.00000000
# query_dense_32_164.graph                    168.00000000             168      0.00000000
# query_dense_32_190.graph                     48.00000000              48      0.00000000

# %%
import math
import re

# === 文件路径 ===
est_file = "/home/wangshuo/projects/FaSTest-main/dataset/sv/sv_estimate_result.txt"
ans_file = "/home/wangshuo/projects/FaSTest-main/dataset/yeast_exp/yeast_exp_ans.txt"

# === 读取真实值 ===
true_values = {}
with open(ans_file, "r") as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) >= 3:
            query_name = parts[0].strip()
            try:
                true_val = float(parts[-1])
                true_values[query_name] = true_val
            except ValueError:
                pass

# === 读取估计结果 ===
results = {}
current_query = None
current_sum = 0.0
current_all_est = None

with open(est_file, "r") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Query:"):
            # 保存上一个 query 的结果
            if current_query is not None:
                results[current_query] = (current_sum, current_all_est)
            # 提取新 query 名称
            m = re.search(r"([^/\\]+\.graph)", line)
            if m:
                current_query = m.group(1)
                current_sum = 0.0
                current_all_est = None

        elif line.startswith("All Est:"):
            try:
                current_all_est = float(line.split(":")[1].strip())
            except ValueError:
                current_all_est = None

        elif line.startswith("----------------------------------------"):
            if current_query is not None:
                results[current_query] = (current_sum, current_all_est)
                current_query = None

        else:
            # 节点估计行
            parts = line.split()
            if len(parts) >= 2:
                try:
                    val = float(parts[1])
                    current_sum += val
                except ValueError:
                    pass

# 最后一段
if current_query is not None:
    results[current_query] = (current_sum, current_all_est)

# === 计算 log(Q_error) 并收集排序用数据 ===
records = []
for q, (est_sum, all_est) in results.items():
    true_val = true_values.get(q)
    if true_val is None or true_val <= 0:
        log_q_error = float("inf")
        log_q_error_all = float("inf")
    else:
        # 对 sum 与 all_est 分别计算误差
        log_q_error = (
            float("inf")
            if est_sum <= 0
            else math.log10(max(est_sum / true_val, true_val / est_sum))
        )
        log_q_error_all = (
            float("inf")
            if all_est is None or all_est <= 0
            else math.log10(max(all_est / true_val, true_val / all_est))
        )
    records.append((q, est_sum, all_est, true_val, log_q_error, log_q_error_all))

# === 按 log(Q_error_AllEst) 降序排列 ===
records.sort(key=lambda x: (float("inf") if math.isnan(x[5]) else x[5]), reverse=True)

# === 输出结果 ===
print(f"{'Query':40} {'SumEst':>12} {'AllEst':>12} {'TrueVal':>12} {'logQ(Sum)':>12} {'logQ(All)':>12}")
print("-" * 95)
for q, est_sum, all_est, true_val, log_q_error, log_q_error_all in records:
    tval = "N/A" if true_val is None else f"{true_val:.0f}"
    log_sum = "INF" if math.isinf(log_q_error) else f"{log_q_error:.6f}"
    log_all = "INF" if math.isinf(log_q_error_all) else f"{log_q_error_all:.6f}"
    all_est_str = "N/A" if all_est is None else f"{all_est:.8f}"
    print(f"{q:40} {est_sum:12.8f} {all_est_str:>12} {tval:>12} {log_sum:>12} {log_all:>12}")
# Out:
# Query                                          SumEst       AllEst      TrueVal    logQ(Sum)    logQ(All)
# -----------------------------------------------------------------------------------------------
# query_dense_32_108.graph                 435911.00000000 99873.10000000       395982     0.041722     0.598227
# query_sparse_24_12.graph                   0.00000000 696864000000.00000000 2100539474505          INF     0.479183
# query_dense_24_61.graph                    0.00000000 113262000.00000000     53111964          INF     0.328892
# query_dense_32_49.graph                  398665000.00000000 81987300.00000000    133237581     0.475981     0.210880
# query_dense_24_12.graph                  2917525900.00000000 2917530000.00000000   3819575411     0.117000     0.117000
# query_sparse_16_181.graph                12308830.00000000 12308800.00000000     15976816     0.113273     0.113275
# query_sparse_32_79.graph                 5936430.00000000 5936430.00000000      5968620     0.002349     0.002349
# query_sparse_8_111.graph                 215873.94000000 215874.00000000       217008     0.002276     0.002275
# query_dense_24_55.graph                  15359.60000000 15359.60000000        15440     0.002267     0.002267
# query_dense_24_29.graph                  206845.00000000 206845.00000000       207900     0.002209     0.002209
# query_sparse_32_44.graph                 7180803300.00000000 7180800000.00000000   7145776592     0.002124     0.002123
# query_sparse_24_21.graph                 15841800.00000000 15841800.00000000     15767136     0.002052     0.002052
# query_dense_32_13.graph                  919206.00000000 919206.00000000       922634     0.001617     0.001617
# query_dense_16_86.graph                  17721.00000000 17721.00000000        17784     0.001541     0.001541
# query_dense_16_37.graph                  4485.60000000 4485.60000000         4470     0.001513     0.001513
# query_dense_32_72.graph                  391.64400000 391.64400000          393     0.001501     0.001501
# query_dense_32_61.graph                  105909.00000000 105909.00000000       105588     0.001318     0.001318
# query_dense_24_73.graph                  69995.10000000 69995.10000000        70200     0.001269     0.001269
# query_dense_32_97.graph                  11343.75000000 11343.70000000        11376     0.001233     0.001235
# query_dense_32_67.graph                  7180.80000000 7180.80000000         7200     0.001160     0.001160
# query_dense_32_21.graph                  7647.20000000 7647.20000000         7628     0.001092     0.001092
# query_dense_16_31.graph                   15.03000000  15.03000000           15     0.000868     0.000868
# query_dense_32_45.graph                  319646.00000000 319646.00000000       320256     0.000828     0.000828
# query_dense_32_120.graph                 12982.00000000 12982.00000000        12960     0.000737     0.000737
# query_sparse_24_23.graph                 3027770000.00000000 3027770000.00000000   3026263122     0.000216     0.000216
# query_sparse_32_135.graph                62685.00000000 62685.00000000        62700     0.000104     0.000104
# query_sparse_24_49.graph                 174210300000.00000000 174210000000.00000000 174211517750     0.000003     0.000004
# query_dense_4_133.graph                  722.00000000 722.00000000          722     0.000000     0.000000
# query_dense_4_155.graph                    1.00000000   1.00000000            1     0.000000     0.000000
# query_dense_4_169.graph                   19.00000000  19.00000000           19     0.000000     0.000000
# query_dense_4_199.graph                  1039.00000000 1039.00000000         1039     0.000000     0.000000
# query_dense_16_2.graph                    36.00000000  36.00000000           36     0.000000     0.000000
# query_dense_16_166.graph                  96.00000000  96.00000000           96     0.000000     0.000000
# query_dense_24_40.graph                  495.00000000 495.00000000          495     0.000000     0.000000
# query_dense_24_59.graph                    3.00000000   3.00000000            3     0.000000     0.000000
# query_dense_24_71.graph                  128.00000000 128.00000000          128     0.000000     0.000000
# query_dense_24_97.graph                  140.00000000 140.00000000          140     0.000000     0.000000
# query_dense_24_105.graph                 3024.00000000 3024.00000000         3024     0.000000     0.000000
# query_dense_24_174.graph                 192.00000000 192.00000000          192     0.000000     0.000000
# query_dense_32_19.graph                  1610.00000000 1610.00000000         1610     0.000000     0.000000
# query_dense_32_64.graph                  1152.00000000 1152.00000000         1152     0.000000     0.000000
# query_dense_32_74.graph                  5616.00000000 5616.00000000         5616     0.000000     0.000000
# query_dense_32_79.graph                  15552.00000000 15552.00000000        15552     0.000000     0.000000
# query_sparse_16_2.graph                   96.00000000  96.00000000           96     0.000000     0.000000
# query_dense_32_135.graph                  60.00000000  60.00000000           60     0.000000     0.000000
